# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %% [markdown]
# Installation Steps

# %%
# !pip install git+https://github.com/openai/whisper.git 
# !pip install ffmpeg-python
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /private/var/folders/vw/_k6w_xh97_xb3bkd57dznybm0000gn/T/pip-req-build-t1a3fqfz
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /private/var/folders/vw/_k6w_xh97_xb3bkd57dznybm0000gn/T/pip-req-build-t1a3fqfz
#   Resolved https://github.com/openai/whisper.git to commit 517a43ecd132a2089d85f4ebc044728a71d49f6e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: more-itertools in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from openai-whisper==20240930) (10.6.0)
# Requirement already satisfied: numba in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from openai-whisper==20240930) (0.61.2)
# Requirement already satisfied: numpy in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from openai-whisper==20240930) (2.2.4)
# Requirement already satisfied: tiktoken in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from openai-whisper==20240930) (0.9.0)
# Requirement already satisfied: torch in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from openai-whisper==20240930) (2.6.0)
# Requirement already satisfied: tqdm in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from openai-whisper==20240930) (4.66.4)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from numba->openai-whisper==20240930) (0.44.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from tiktoken->openai-whisper==20240930) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from tiktoken->openai-whisper==20240930) (2.32.3)
# Requirement already satisfied: filelock in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (4.12.2)
# Requirement already satisfied: networkx in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (3.1.6)
# Requirement already satisfied: fsspec in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (2025.3.2)
# Requirement already satisfied: setuptools in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from torch->openai-whisper==20240930) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch->openai-whisper==20240930) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240930) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/samuelturner/miniconda3/lib/python3.12/site-packages (from jinja2->torch->openai-whisper==20240930) (3.0.2)
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting future (from ffmpeg-python)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-1.0.0

# %%
# !brew install ffmpeg
# Out:
# ==> Auto-updating Homebrew...
# Adjust how often this is run with HOMEBREW_AUTO_UPDATE_SECS or disable with
# HOMEBREW_NO_AUTO_UPDATE. Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Downloading https://ghcr.io/v2/homebrew/portable-ruby/portable-ruby/blobs/sha256:d9faa506c014dedc0b034a68103ba75c9a58242f4d6c67b6ca0f649c39602bcf
# ######################################################################### 100.0%
# ==> Pouring portable-ruby-3.3.7.arm64_big_sur.bottle.tar.gz
# ==> Homebrew collects anonymous analytics.
# Read the analytics documentation (and how to opt-out) here:
#   https://docs.brew.sh/Analytics
# No analytics have been recorded yet (nor will be during this `brew` run).
#
# ==> Homebrew is run entirely by unpaid volunteers. Please consider donating:
#   https://github.com/Homebrew/brew#donations
#
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# ab-av1                                   libkeyfinder
# acme.sh                                  libmsquic
# acronym                                  libnice-gstreamer
# action-docs                              libparserutils
# ad                                       libpg_query
# adapterremoval                           libpostal
# adaptivecpp                              libpostal-rest
# afl++                                    librime
# aicommit                                 libsidplayfp
# algolia                                  libspelling@0.2
# aliae                                    libsvgtiny
# alive2                                   libtatsu
# alloy                                    libultrahdr
# ampl-asl                                 libunicode
# ansible-builder                          libxsd-frontend
# ansible@10                               limbo
# anubis                                   lla
# anyquery                                 lld
# apache-flink@1                           lld@19
# aqtinstall                               llvm@18
# aqua                                     llvm@19
# arelo                                    localai
# argtable3                                lol-html
# astroterm                                ltex-ls-plus
# async_simple                             ludusavi
# atac                                     lume
# aws-c-auth                               m68k-elf-binutils
# aws-c-cal                                m68k-elf-gcc
# aws-c-common                             mac
# aws-c-compression                        macmon
# aws-c-event-stream                       maeparser
# aws-c-http                               mago
# aws-c-io                                 malcontent
# aws-c-mqtt                               mani
# aws-c-s3                                 marisa
# aws-c-sdkutils                           markdown-oxide
# aws-checksums                            marmite
# aws-crt-cpp                              martin
# azqr                                     mbpoll
# azure-core-cpp                           mcpm
# azure-storage-blobs-cpp                  md2pdf
# azure-storage-common-cpp                 mdq
# azurehound                               mdz
# babelfish                                meli
# bacon-ls                                 mergiraf
# bagels                                   minijinja-cli
# bazel@7                                  minio-warp
# beanquery                                mkdocs-material
# beautysh                                 mmdbctl
# behaviortree.cpp                         mob
# bender                                   monocle
# bibtex-tidy                              mox
# binocle                                  mummer
# binsider                                 nak
# blisp                                    nanobind
# block-goose-cli                          neocmakelsp
# bold                                     netatalk
# bombardier                               netfetch
# boring                                   neverest
# bpmnlint                                 nmstatectl
# bruno-cli                                node-red
# c2patool                                 node@22
# carapace                                 nom
# cargo-cache                              nping
# cargo-chef                               nrm
# cargo-cyclonedx                          nuitka
# cargo-dist                               odbc2parquet
# cargo-expand                             onnx
# cargo-flamegraph                         openapi-diff
# cargo-hack                               openapi-tui
# cargo-msrv                               oranda
# cargo-public-api                         org-formation
# cargo-run-bin                            otel-cli
# cargo-shuttle                            otterdog
# cargo-sort                               ov
# cargo-spellcheck                         oxlint
# cargo-update                             paperjam
# catgirl                                  parallel-disk-usage
# cbfmt                                    parca
# cdncheck                                 parlay
# cf-terraforming                          pdfly
# cfnctl                                   percona-server@8.0
# chaos-client                             percona-xtrabackup@8.0
# chdig                                    periphery
# chiko                                    perl-dbd-mysql
# clickhouse-sql-parser                    pgbackrest
# cljfmt                                   pgrx
# cloud-provider-kind                      php@8.3
# cloudfoundry-cli                         physunits
# cloudquery                               pie
# cmake-lint                               pinact
# cobo-cli                                 pipelight
# cobra-cli                                pipet
# code2prompt                              pistache
# codeberg-cli                             pivy
# codesnap                                 pixi-pack
# codevis                                  pkgx
# comrak                                   pkl-lsp
# comtrya                                  planus
# coordgen                                 pnpm@9
# cot                                      polkit
# cpp-lazy                                 poselib
# cpp-peglib                               postgresql-hll
# crates-tui                               postgresql@17
# crossplane                               posting
# cspell                                   precious
# cyphernetes                              prism-cli
# darklua                                  probe-rs-tools
# dbg-macro                                projectable
# dblab                                    protobuf@29
# decasify                                 protoc-gen-grpc-java
# decompose                                proxyfor
# diary                                    pscale
# dipc                                     punktf
# directx-headers                          pytest
# dish                                     python-freethreading
# distill-cli                              python-gdbm@3.13
# djlint                                   python-tk@3.13
# dockcheck                                python@3.13
# dockerfilegraph                          qbec
# dockerfmt                                ra-multiplex
# dotnet@8                                 rainfrog
# dpic                                     ramalama
# draft                                    rapidyaml
# dragonbox                                rasterio
# dry                                      ratarmount
# dtsroll                                  ratify
# ducker                                   rattler-index
# dud                                      recc
# dug                                      redka
# dum                                      redocly-cli
# dvr-scan                                 regal
# dyff                                     render
# easyeda2kicad                            replxx
# energy                                   repren
# ente-cli                                 restish
# erlang@26                                reuse
# eslint_d                                 reveal-md
# evans                                    rhai
# eventpp                                  rink
# evil-helix                               rip2
# excalidraw-converter                     rmtrash
# exomizer                                 rogcat
# fabric-ai                                roxctl
# facad                                    rpds-py
# fairy-stockfish                          rsgain
# falcosecurity-libs                       rshijack
# fancy-cat                                ruby-lsp
# fastbuild                                ruby@3.3
# fastly                                   runitor
# fcft                                     rust-script
# fedify                                   rustic
# feluda                                   rustywind
# fileql                                   s5cmd
# fiona                                    sby
# fish-lsp                                 scooter
# flang                                    screenpipe
# flow-control                             scryer-prolog
# fltk@1.3                                 sdl3
# foot                                     sdl3_image
# fortitude                                sdl3_ttf
# fortran-stdlib                           semver
# foundry                                  sendme
# fpm                                      sentry-cli
# fricas                                   sentry-native
# ftxui                                    sequin
# funzzy                                   sequoia-sq
# fzf-make                                 sequoia-sqv
# gama                                     serie
# gamdl                                    sesh
# garnet                                   setconf
# gauth                                    sf
# gci                                      sfml@2
# gcr                                      sfsexp
# gdown                                    shepherd
# gdtoolkit                                showcert
# geesefs                                  shuttle
# gersemi                                  sidekick
# ggh                                      sigsum-go
# gh-ost                                   sitefetch
# ghc@9.10                                 sixtunnel
# git-graph                                sleek
# git-ignore                               slepc
# git-mob                                  slepc-complex
# git-spice                                slumber
# git-who                                  snowflake-cli
# github-mcp-server                        soft-serve
# glaze                                    spytrap-adb
# glibc@2.17                               sql-formatter
# globstar                                 sqlitecpp
# gnome-builder                            sshx
# gnome-online-accounts                    starlark-rust
# go-blueprint                             statesmith
# go-parquet-tools                         static-web-server
# go@1.23                                  streamrip
# goimports                                sttr
# goku                                     superhtml
# gomi                                     surfer
# gopeed                                   sv2v
# gotz                                     swc
# gowall                                   swctl
# goyacc                                   symfony-cli
# gplugin                                  synchrony
# gptme                                    sysprof
# grafana-alloy                            tabulate
# graphql-inspector                        tach
# gsan                                     talosctl
# gtree                                    taskflow
# guile-fibers                             tcl-tk@8
# gurk                                     television
# gut                                      templ
# harlequin                                tenere
# harper                                   termbg
# harsh                                    termscp
# havener                                  terraform-cleaner
# havn                                     terraform-iam-policy-validator
# hawkeye                                  tex-fmt
# hcledit                                  text-embeddings-inference
# heroku                                   tf-summarize
# hevi                                     tfcmt
# hgrep                                    tfocus
# hishtory                                 tfprovidercheck
# hjson                                    tgpt
# hk                                       the-way
# hl                                       threatcl
# html2markdown                            tiny
# hub-tool                                 tinysparql
# humanlog                                 tllist
# hypopg                                   tml
# i686-elf-grub                            tmux-sessionizer
# icann-rdap                               todoist
# icu4c@74                                 tomcat@10
# icu4c@75                                 toml2json
# icu4c@76                                 topiary
# icu4c@77                                 trdsql
# identme                                  tsui
# idsgrep                                  tuisky
# iguana                                   twitch-cli
# imgp                                     typeshare
# immich-go                                typioca
# inchi                                    typos-lsp
# infisical                                tzdb
# ipatool                                  ubi
# is-fast                                  umka-lang
# jaguar                                   umockdev
# jenkins-cli                              unciv
# jikken                                   vals
# jira-cli                                 veccore
# json2hcl                                 versitygw
# jsrepo                                   veryfasttree
# jupytext                                 vfkit
# jwt-cli                                  vgt
# jxl-oxide                                victorialogs
# kafkactl                                 vimtutor-sequel
# kamal-proxy                              vipsdisp
# kanata                                   visidata
# kapp                                     vo-amrwbenc
# kbld                                     vscli
# keep-sorted                              vue-language-server
# keeper-commander                         wails
# keyutils                                 wasi-libc
# kfr                                      wasi-runtimes
# kirimase                                 wasm-component-ld
# koji                                     watcher
# kool                                     wcstools
# kraftkit                                 weaviate
# krep                                     weaviate-cli
# ktexttemplate                            wfa2-lib
# kty                                      wgo
# kube-bench                               wthrr
# kubeone                                  x-cmd
# kubernetes-cli@1.31                      x86_64-elf-grub
# kubetail                                 xan
# kubetrim                                 xc
# kuzco                                    xcresultparser
# langgraph-cli                            xeyes
# languagetool-rust                        xk6
# largetifftools                           xlsclients
# lavat                                    xmq
# lazyjj                                   xprop
# lazyjournal                              xtermcontrol
# lazysql                                  xwininfo
# lbfgspp                                  yalantinglibs
# leetcode-cli                             yamlfix
# leetgo                                   yices2
# legba                                    yoke
# libcdio-paranoia                         yor
# libcotp                                  yozefu
# libcss                                   ytt
# libcutl                                  yutu
# libdex                                   zigup
# libdom                                   zimfw
# libesedb                                 zizmor
# libformfactor                            zlib-ng-compat
# libgit2@1.8                              zlib-rs
# libgoa                                   zns
# libgudev                                 zsh-f-sy-h
# libheinz                                 zsh-system-clipboard
# libhubbub
# ==> New Casks
# ableset                                  font-playwrite-us-trad-guides
# ace-studio                               font-playwrite-vn-guides
# acronis-true-image-cleanup-tool          font-playwrite-za-guides
# adlock                                   font-pochaevsk
# advanced-renamer                         font-ponomar
# agent-tars                               font-pretendard-gov
# aide-app                                 font-recursive-desktop
# alcove                                   font-sf-mono-nerd-font-ligaturized
# amiberry                                 font-shafarik
# antinote                                 font-sketchybar-app-font
# anytype@alpha                            font-sour-gummy
# anytype@beta                             font-source-han-code-jp
# archivewebpage                           font-special-gothic
# atv-remote                               font-special-gothic-condensed-one
# autogram                                 font-special-gothic-expanded-one
# automounterhelper                        font-suse
# aw-edid-editor                           font-tagesschrift
# ayugram                                  font-tamzen
# ba-connected                             font-triodion
# backyard-ai                              font-udev-gothic-hs
# badgeify                                 font-webdings
# bambu-connect                            font-winky-rough
# bananas                                  font-winky-sans
# batfi                                    font-zpix
# beaver-notes                             fontcreator
# bentobox                                 freelens
# beutl                                    fujifilm-tether-app
# beyond-compare@4                         furtherance
# bindiff                                  fuse-t
# block-goose                              ghostty
# bobhelper                                ghostty@tip
# bookmacster@beta                         github-copilot-for-xcode
# browser-actions                          gologin
# caido                                    gpt4all
# candy-crisis                             granola
# cap                                      grayjay
# captainplugins                           green-go-control
# ccstudio                                 halion-sonic
# charles@4                                hamrs-pro
# chatwise                                 helio
# cherry-studio                            helpwire-operator
# chime@alpha                              homerow
# chordpotion                              huggingchat
# claude                                   huly
# clipbook                                 hy-rpe2
# cloudflare-warp@beta                     hyperconnect
# cocoapacketanalyzer                      ijhttp
# colemak-dh                               ik-product-manager
# colemak-dhk                              imaging-edge
# comfyui                                  imaging-edge-webcam
# companion                                inmusic-software-center
# companion-satellite                      irpf2025
# companion@beta                           ishare
# consul                                   istatistica-core
# coterm                                   istherenet
# cpu-info                                 jet-pilot
# dana-dex                                 jottacloud
# dante-controller                         jumpcloud-password-manager
# dante-via                                k6-studio
# default-handler                          kate
# dehesselle-meld                          keyguard
# desktime                                 kilohearts-installer
# display-pilot                            kimis
# displaybuddy                             kunkun
# djstudio                                 label-live
# djuced                                   langgraph-studio
# dockfix                                  last-window-quits
# dockside                                 leader-key
# dorico                                   legcord
# earnapp                                  lets
# excalidrawz                              linearmouse@beta
# excire-foto                              localsend
# fastdmg                                  losslessswitcher
# fathom                                   luanti
# flashspace                               lunatask
# flowvision                               lyric-fever
# focu                                     macai
# follow@alpha                             macskk
# font-42dot-sans                          magicquit
# font-adwaita                             mailbird
# font-agave                               mailsteward
# font-agu-display                         meridiem
# font-aporetic                            microsoft-edge@canary
# font-atkinson-hyperlegible-mono          mihomo-party
# font-atkinson-hyperlegible-next          mindmaster-cn
# font-badeen-display                      minstaller
# font-big-shoulders                       mitti
# font-big-shoulders-inline                mixing-station
# font-big-shoulders-stencil               moment
# font-bitcount                            morisawa-desktop-manager
# font-bitcount-prop-single-ink            mouseless
# font-bitcount-single-ink                 mouseless@preview
# font-boldonse                            muteme
# font-brass-mono                          mythic
# font-bravura                             ndi-tools
# font-bungee-tint                         neohtop
# font-bytesized                           nethlink
# font-cica-without-emoji                  nexonplug
# font-comic-relief                        nvidia-nsight-compute
# font-coral-pixels                        nvidia-nsight-systems
# font-departure-mono-nerd-font            obscura-vpn
# font-doto                                octarine
# font-edu-au-vic-wa-nt-arrows             ontime
# font-edu-au-vic-wa-nt-dots               open-eid
# font-edu-au-vic-wa-nt-guides             openchrom
# font-edu-au-vic-wa-nt-pre                openhv
# font-eldur                               opera-air
# font-epunda-sans                         oracle-jdk-javadoc@21
# font-epunda-slab                         ovice
# font-exile                               pairpods
# font-faculty-glyphic                     pareto-security
# font-fairfax-hd                          pastenow
# font-funnel-display                      pdl
# font-funnel-sans                         pinwheel
# font-gd-highwaygothicja                  pixel-shift-combiner
# font-greybeard                           pixpin
# font-host-grotesk                        precize
# font-ibm-plex-sans-sc                    qobuz-downloader
# font-kanchenjunga                        qt-design-studio
# font-kreative-square                     quba
# font-libertinus-mono                     radiola
# font-liter                               rave
# font-lxgw-wenkai-gb-lite                 readest
# font-maple-mono-cn                       repo-prompt
# font-maple-mono-nf                       restapia
# font-maple-mono-nf-cn                    restic-browser
# font-maple-mono-normal                   rivet
# font-maple-mono-normal-cn                rode-unify
# font-maple-mono-normal-nf                rode-virtual-channels
# font-maple-mono-normal-nf-cn             rouvy
# font-matemasie                           sanctum
# font-miracode                            satdump
# font-moderustic                          satyrn
# font-monomakh                            serial-studio
# font-montserrat-underline                shortwave
# font-moralerspace                        silhouette-studio
# font-moralerspace-hw                     singlebox
# font-moralerspace-hw-jpdoc               sketchup
# font-moralerspace-hw-nf                  slidepad
# font-moralerspace-jpdoc                  sokim
# font-moralerspace-nf                     soundanchor
# font-mynaui-icons                        soundsource@test
# font-nanum-square                        spectrolite
# font-nanum-square-neo                    stability-matrix
# font-nanum-square-round                  startupfolder
# font-new-amsterdam                       steinberg-download-assistant
# font-new-computer-modern                 steinberg-library-manager
# font-noto-serif-todhri                   steinberg-mediabay
# font-parkinsans                          stratoshark
# font-pixel-code                          stratoshark@dev
# font-playpen-sans-arabic                 structuredlogviewer
# font-playpen-sans-deva                   superwhisper
# font-playpen-sans-hebrew                 supremo
# font-playpen-sans-thai                   swift-shift
# font-playwrite-ar-guides                 synology-image-assistant
# font-playwrite-at-guides                 sys-pc-tool
# font-playwrite-au-nsw-guides             tabtab
# font-playwrite-au-qld-guides             tal-drum
# font-playwrite-au-sa-guides              taskbar
# font-playwrite-au-tas-guides             tdr-molotok
# font-playwrite-au-vic-guides             tdr-prism
# font-playwrite-be-vlg-guides             teleport
# font-playwrite-be-wal-guides             termora
# font-playwrite-br-guides                 testfully
# font-playwrite-ca-guides                 thelowtechguys-cling
# font-playwrite-cl-guides                 thumbhost3mf
# font-playwrite-co-guides                 thunderbird@esr
# font-playwrite-cu-guides                 tm-error-logger
# font-playwrite-cz-guides                 tpvirtual
# font-playwrite-de-grund-guides           trae
# font-playwrite-de-la-guides              trae-cn
# font-playwrite-de-sas-guides             triliumnext-notes
# font-playwrite-de-va-guides              turbotax-2024
# font-playwrite-dk-loopet-guides          typefully
# font-playwrite-dk-uloopet-guides         ua-midi-control
# font-playwrite-es-deco-guides            ui-tars
# font-playwrite-es-guides                 unraid-usb-creator-next
# font-playwrite-fr-moderne-guides         valhalla-freq-echo
# font-playwrite-fr-trad-guides            valhalla-space-modulator
# font-playwrite-gb-j-guides               valhalla-supermassive
# font-playwrite-gb-s-guides               veracrypt-fuse-t
# font-playwrite-hr-guides                 vernier-spectral-analysis
# font-playwrite-hr-lijeva-guides          vesktop
# font-playwrite-hu-guides                 vezer
# font-playwrite-id-guides                 vienna-assistant
# font-playwrite-ie-guides                 viz
# font-playwrite-in-guides                 voiceink
# font-playwrite-is-guides                 webkinz
# font-playwrite-it-moderna-guides         website-audit
# font-playwrite-it-trad-guides            whimsical
# font-playwrite-mx-guides                 widgettoggler
# font-playwrite-ng-modern-guides          windowkeys
# font-playwrite-nl-guides                 windows-app
# font-playwrite-no-guides                 windsurf
# font-playwrite-nz-guides                 windsurf@next
# font-playwrite-pe-guides                 wiso-steuer-2025
# font-playwrite-pl-guides                 wizcli
# font-playwrite-pt-guides                 yaak@beta
# font-playwrite-ro-guides                 yellowdot
# font-playwrite-sk-guides                 zen-browser@twilight
# font-playwrite-tz-guides                 zoom-m3-edit-and-play
# font-playwrite-us-modern-guides
#
# You have 7 outdated formulae installed.
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/ffmpeg/manifests/7.1.1_1
# ######################################################################### 100.0%
# ==> Fetching dependencies for ffmpeg: brotli, giflib, highway, imath, jpeg-turbo, libpng, xz, lz4, zstd, libtiff, little-cms2, libdeflate, openexr, webp, jpeg-xl, libvmaf, aom, aribb24, dav1d, freetype, fontconfig, frei0r, ca-certificates, gmp, libunistring, gettext, libidn2, libtasn1, nettle, p11-kit, openssl@3, libevent, libnghttp2, unbound, gnutls, glib, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, graphite2, icu4c@77, harfbuzz, lame, fribidi, libunibreak, libass, libbluray, cjson, libmicrohttpd, mbedtls, librist, libsoxr, libssh, libvidstab, libogg, libvorbis, libvpx, opencore-amr, openjpeg, opus, rav1e, libsamplerate, flac, mpg123, libsndfile, rubberband, sdl2, snappy, speex, srt, svt-av1, leptonica, libb2, libarchive, pango, tesseract, theora, x264, x265, xvid, libsodium, zeromq and zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/manifests/1.1.0-2
# ######################################################################### 100.0%
# ==> Fetching brotli
# ==> Downloading https://ghcr.io/v2/homebrew/core/brotli/blobs/sha256:64750425b75
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.2
# ######################################################################### 100.0%
# ==> Fetching giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:bf188a3d3e3
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.2.0
# ######################################################################### 100.0%
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:8a33276294
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.12
# ######################################################################### 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:946c5c054145
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/3.1.0
# ######################################################################### 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:c43b108
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.47
# ######################################################################### 100.0%
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:b4a7f252793
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.8.1
# ######################################################################### 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:dcd7823f2624cbc
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.10.0-1
# ######################################################################### 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:5bd143b7b78498
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.7
# ######################################################################### 100.0%
# ==> Fetching zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:b039c851ef226
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.7.0-1
# ######################################################################### 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:5f771cedcb
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.17
# ######################################################################### 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:3827b5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libdeflate/manifests/1.23
# ######################################################################### 100.0%
# ==> Fetching libdeflate
# ==> Downloading https://ghcr.io/v2/homebrew/core/libdeflate/blobs/sha256:0a70dfd
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.3.3
# ######################################################################### 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:095b03c2de
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.5.0
# ######################################################################### 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:700e1f0c8a32f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.11.1_1
# ######################################################################### 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:c3aceba825
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/3.0.0-1
# ######################################################################### 100.0%
# ==> Fetching libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:0809635a52
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.12.0
# ######################################################################### 100.0%
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:0bddb3845d42ff
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/manifests/1.0.4
# ######################################################################### 100.0%
# ==> Fetching aribb24
# ==> Downloading https://ghcr.io/v2/homebrew/core/aribb24/blobs/sha256:4f5a5fb9f9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/manifests/1.5.1
# ######################################################################### 100.0%
# ==> Fetching dav1d
# ==> Downloading https://ghcr.io/v2/homebrew/core/dav1d/blobs/sha256:2cfb486c742f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.3
# ######################################################################### 100.0%
# ==> Fetching freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:bcd39d3a5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.16.0
# ######################################################################### 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:c3a7405
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/manifests/2.3.3
# ######################################################################### 100.0%
# ==> Fetching frei0r
# ==> Downloading https://ghcr.io/v2/homebrew/core/frei0r/blobs/sha256:064f58d2911
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2025-
# ######################################################################### 100.0%
# ==> Fetching ca-certificates
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:8f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/manifests/6.3.0
# ######################################################################### 100.0%
# ==> Fetching gmp
# ==> Downloading https://ghcr.io/v2/homebrew/core/gmp/blobs/sha256:6683d73d6677d2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.3
# ######################################################################### 100.0%
# ==> Fetching libunistring
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:3cd26
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.24
# ######################################################################### 100.0%
# ==> Fetching gettext
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:be3555b4d0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.8
# ######################################################################### 100.0%
# ==> Fetching libidn2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:1eb02bfa40
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/manifests/4.20.0
# ######################################################################### 100.0%
# ==> Fetching libtasn1
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtasn1/blobs/sha256:e847b97b8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/manifests/3.10.1
# ######################################################################### 100.0%
# ==> Fetching nettle
# ==> Downloading https://ghcr.io/v2/homebrew/core/nettle/blobs/sha256:df8b22b1a4d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/manifests/0.25.5-1
# ######################################################################### 100.0%
# ==> Fetching p11-kit
# ==> Downloading https://ghcr.io/v2/homebrew/core/p11-kit/blobs/sha256:a411c52306
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/manifests/3.4.1
# ######################################################################### 100.0%
# ==> Fetching openssl@3
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/3/blobs/sha256:b20c7d9b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/manifests/2.1.12_1
# ######################################################################### 100.0%
# ==> Fetching libevent
# ==> Downloading https://ghcr.io/v2/homebrew/core/libevent/blobs/sha256:65fc7c61f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.65.0
# ######################################################################### 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:492e4da
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/manifests/1.22.0
# ######################################################################### 100.0%
# ==> Fetching unbound
# ==> Downloading https://ghcr.io/v2/homebrew/core/unbound/blobs/sha256:b1b2f3ec33
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/manifests/3.8.9
# ######################################################################### 100.0%
# ==> Fetching gnutls
# ==> Downloading https://ghcr.io/v2/homebrew/core/gnutls/blobs/sha256:eaf32401a72
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.84.0_1
# ######################################################################### 100.0%
# ==> Fetching dependencies for glib: pcre2
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/manifests/10.45
# ######################################################################### 100.0%
# ==> Fetching pcre2
# ==> Downloading https://ghcr.io/v2/homebrew/core/pcre2/blobs/sha256:f2abc87de679
# ######################################################################### 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:c21897f373620
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2024.1
# ######################################################################### 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:91066363
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.12
# ######################################################################### 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:e8a5fedbd9e
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.5
# ######################################################################### 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:b09a915da
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.17.0-1
# ######################################################################### 100.0%
# ==> Fetching libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:cce8d9e12c3
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.12
# ######################################################################### 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:57ccd55767f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.6
# ######################################################################### 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:a0434e871b
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.12
# ######################################################################### 100.0%
# ==> Fetching libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:edcb888
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################### 100.0%
# ==> Fetching lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:6bb0401c41a18f
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.44.2
# ######################################################################### 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:8ec43a3f69d
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.18.4
# ######################################################################### 100.0%
# ==> Fetching cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:6b2d148a34a6
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################### 100.0%
# ==> Fetching graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:150b286a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/77/manifests/77.1
# ######################################################################### 100.0%
# ==> Fetching icu4c@77
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/77/blobs/sha256:19f6b5fef
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/11.0.1
# ######################################################################### 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:c4f555002
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lame/manifests/3.100
# ######################################################################### 100.0%
# ==> Fetching lame
# ==> Downloading https://ghcr.io/v2/homebrew/core/lame/blobs/sha256:0ae0dcb09c908
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.16
# ######################################################################### 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:4904bb3375
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/manifests/6.1
# ######################################################################### 100.0%
# ==> Fetching libunibreak
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunibreak/blobs/sha256:0bed33
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/manifests/0.17.3
# ######################################################################### 100.0%
# ==> Fetching libass
# ==> Downloading https://ghcr.io/v2/homebrew/core/libass/blobs/sha256:2c948ddd9b7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/manifests/1.3.4
# ######################################################################### 100.0%
# ==> Fetching libbluray
# ==> Downloading https://ghcr.io/v2/homebrew/core/libbluray/blobs/sha256:82b77156
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/manifests/1.7.18
# ######################################################################### 100.0%
# ==> Fetching cjson
# ==> Downloading https://ghcr.io/v2/homebrew/core/cjson/blobs/sha256:369cf21b89c8
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/manifests/1.0.1
# ######################################################################### 100.0%
# ==> Fetching libmicrohttpd
# ==> Downloading https://ghcr.io/v2/homebrew/core/libmicrohttpd/blobs/sha256:b6b9
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/manifests/3.6.3
# ######################################################################### 100.0%
# ==> Fetching mbedtls
# ==> Downloading https://ghcr.io/v2/homebrew/core/mbedtls/blobs/sha256:d595b50d64
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/manifests/0.2.11
# ######################################################################### 100.0%
# ==> Fetching librist
# ==> Downloading https://ghcr.io/v2/homebrew/core/librist/blobs/sha256:5d585b8708
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsoxr/manifests/0.1.3-1
# ######################################################################### 100.0%
# ...
# ==> Installing ffmpeg dependency: openjpeg
# ==> Downloading https://ghcr.io/v2/homebrew/core/openjpeg/manifests/2.5.3
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/05e309d0892898d6a89fd896da03119707c403fd4cc6877860ec46b66b0946e9--openjpeg-2.5.3.bottle_manifest.json
# ==> Pouring openjpeg--2.5.3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openjpeg/2.5.3: 543 files, 14.5MB
# ==> Installing ffmpeg dependency: opus
# ==> Downloading https://ghcr.io/v2/homebrew/core/opus/manifests/1.5.2
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/ab70a7e8383f42047a27c0638675dbd9c3229997a01eed45d76f174664a4b607--opus-1.5.2.bottle_manifest.json
# ==> Pouring opus--1.5.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/opus/1.5.2: 16 files, 1MB
# ==> Installing ffmpeg dependency: rav1e
# ==> Downloading https://ghcr.io/v2/homebrew/core/rav1e/manifests/0.7.1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/ccafd526f73546dc53bb2cd7d3c8d0e392229423fbc6962740a67633d8b06443--rav1e-0.7.1.bottle_manifest.json
# ==> Pouring rav1e--0.7.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/rav1e/0.7.1: 15 files, 45.8MB
# ==> Installing ffmpeg dependency: libsamplerate
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsamplerate/manifests/0.2.2-1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/6be12485f3237a33a9c98a4799bc5e05f5f6520175c5e08fb3545d0f7f45f9cc--libsamplerate-0.2.2-1.bottle_manifest.json
# ==> Pouring libsamplerate--0.2.2.arm64_sequoia.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/libsamplerate/0.2.2: 33 files, 3MB
# ==> Installing ffmpeg dependency: flac
# ==> Downloading https://ghcr.io/v2/homebrew/core/flac/manifests/1.5.0
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/089760ef9c022b15fbe3b3eaf6297c3ced28db6633ea0c868a569ae651efb325--flac-1.5.0.bottle_manifest.json
# ==> Pouring flac--1.5.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/flac/1.5.0: 40 files, 1.9MB
# ==> Installing ffmpeg dependency: mpg123
# ==> Downloading https://ghcr.io/v2/homebrew/core/mpg123/manifests/1.32.10
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/692cc3a4160f69a557151ff579c20ec779fd22cf3862ccaffd16630b309b237f--mpg123-1.32.10.bottle_manifest.json
# ==> Pouring mpg123--1.32.10.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/mpg123/1.32.10: 34 files, 2.0MB
# ==> Installing ffmpeg dependency: libsndfile
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsndfile/manifests/1.2.2_1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/2e97439a3a58c856a00043feceb29f382febc8542b8a0c0a31aa202b2c93ea08--libsndfile-1.2.2_1.bottle_manifest.json
# ==> Pouring libsndfile--1.2.2_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libsndfile/1.2.2_1: 55 files, 1.8MB
# ==> Installing ffmpeg dependency: rubberband
# ==> Downloading https://ghcr.io/v2/homebrew/core/rubberband/manifests/4.0.0
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/bc9f458d122d070584e4df5d712d01aaa5ba968f72342eb12ff5ec4cc8bb97bb--rubberband-4.0.0.bottle_manifest.json
# ==> Pouring rubberband--4.0.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/rubberband/4.0.0: 15 files, 2.0MB
# ==> Installing ffmpeg dependency: sdl2
# ==> Downloading https://ghcr.io/v2/homebrew/core/sdl2/manifests/2.32.4-1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/19a61f83e224c628352e0a006f92fe25aff996b6f871d76e131b71ae4001e67b--sdl2-2.32.4-1.bottle_manifest.json
# ==> Pouring sdl2--2.32.4.arm64_sequoia.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/sdl2/2.32.4: 94 files, 6.4MB
# ==> Installing ffmpeg dependency: snappy
# ==> Downloading https://ghcr.io/v2/homebrew/core/snappy/manifests/1.2.1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/b2e6bfcdbddf1d451a8dbbb6fc3c44a267b753ac1a889dbb0b9159bf31dacdd5--snappy-1.2.1.bottle_manifest.json
# ==> Pouring snappy--1.2.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/snappy/1.2.1: 19 files, 172.2KB
# ==> Installing ffmpeg dependency: speex
# ==> Downloading https://ghcr.io/v2/homebrew/core/speex/manifests/1.2.1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/483f702af62f72259facb50d3d47cd0bb25c8f0fb887029d30051a8cef860be5--speex-1.2.1.bottle_manifest.json
# ==> Pouring speex--1.2.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/speex/1.2.1: 26 files, 858.2KB
# ==> Installing ffmpeg dependency: srt
# ==> Downloading https://ghcr.io/v2/homebrew/core/srt/manifests/1.5.4
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/33ca2d2d20854c6aeeb9dbcfb98a9721584a29e8e65bc2dcd6764f2792a2af27--srt-1.5.4.bottle_manifest.json
# ==> Pouring srt--1.5.4.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/srt/1.5.4: 21 files, 4.7MB
# ==> Installing ffmpeg dependency: svt-av1
# ==> Downloading https://ghcr.io/v2/homebrew/core/svt-av1/manifests/3.0.2
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/08b707c1ceca9182539fadceb56d5017860f66e31092634bd65d4ee476c6f02d--svt-av1-3.0.2.bottle_manifest.json
# ==> Pouring svt-av1--3.0.2.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/svt-av1/3.0.2: 18 files, 3.2MB
# ==> Installing ffmpeg dependency: leptonica
# ==> Downloading https://ghcr.io/v2/homebrew/core/leptonica/manifests/1.85.0
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/2320341c42605b3b080a8ba021dfdc6e3604906b772b77ad098897c13f8f3186--leptonica-1.85.0.bottle_manifest.json
# ==> Pouring leptonica--1.85.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/leptonica/1.85.0: 57 files, 6.9MB
# ==> Installing ffmpeg dependency: libb2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libb2/manifests/0.98.1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/9bb23dca331f0d74876fa5c769113885b92af8a741a851cdfe99f6dfd420b12d--libb2-0.98.1.bottle_manifest.json
# ==> Pouring libb2--0.98.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libb2/0.98.1: 9 files, 128.9KB
# ==> Installing ffmpeg dependency: libarchive
# ==> Downloading https://ghcr.io/v2/homebrew/core/libarchive/manifests/3.7.9
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/f04d01c4b253301055a36f55e16a7ddb02cac054c6d843f01bdf392a444c8e47--libarchive-3.7.9.bottle_manifest.json
# ==> Pouring libarchive--3.7.9.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libarchive/3.7.9: 65 files, 3.8MB
# ==> Installing ffmpeg dependency: pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.56.3
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/6f0e0f9ffd4d853b6b710a1ab143ecf1dbe833bc2505437fffb38d1a28fef526--pango-1.56.3.bottle_manifest.json
# ==> Pouring pango--1.56.3.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pango/1.56.3: 69 files, 3.4MB
# ==> Installing ffmpeg dependency: tesseract
# ==> Downloading https://ghcr.io/v2/homebrew/core/tesseract/manifests/5.5.0_1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/80222c830e769b570ef864b61224c0ec3aab9f89463210fdf68186334601d28c--tesseract-5.5.0_1.bottle_manifest.json
# ==> Pouring tesseract--5.5.0_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/tesseract/5.5.0_1: 75 files, 33.1MB
# ==> Installing ffmpeg dependency: theora
# ==> Downloading https://ghcr.io/v2/homebrew/core/theora/manifests/1.1.1-4
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/dbefdb4ba8626ac7d284e0da23aaeb705c37e0bfbe0c3c22f05fe5fbcadf10e4--theora-1.1.1-4.bottle_manifest.json
# ==> Pouring theora--1.1.1.arm64_sequoia.bottle.4.tar.gz
# 🍺  /opt/homebrew/Cellar/theora/1.1.1: 98 files, 2MB
# ==> Installing ffmpeg dependency: x264
# ==> Downloading https://ghcr.io/v2/homebrew/core/x264/manifests/r3108
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/8bf7841097db8a60b1789ab16ac7f9395fc5e484932ab958334695a83e804e68--x264-r3108.bottle_manifest.json
# ==> Pouring x264--r3108.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/x264/r3108: 12 files, 4.1MB
# ==> Installing ffmpeg dependency: x265
# ==> Downloading https://ghcr.io/v2/homebrew/core/x265/manifests/4.1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/00181b764f312cf999d1cb444cebe5e64cc140e907858615976053380f6591e3--x265-4.1.bottle_manifest.json
# ==> Pouring x265--4.1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/x265/4.1: 12 files, 11.2MB
# ==> Installing ffmpeg dependency: xvid
# ==> Downloading https://ghcr.io/v2/homebrew/core/xvid/manifests/1.3.7
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/b5121b85b4f5dfe07f78abbcbe520ae4926d781af3342e318e588b62aba59fe0--xvid-1.3.7.bottle_manifest.json
# ==> Pouring xvid--1.3.7.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xvid/1.3.7: 11 files, 1.2MB
# ==> Installing ffmpeg dependency: libsodium
# ==> Downloading https://ghcr.io/v2/homebrew/core/libsodium/manifests/1.0.20
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/a9a9a2e1207e214070682a14f6470fb686cbb6ba7c24c2c747c0ca0663f42557--libsodium-1.0.20.bottle_manifest.json
# ==> Pouring libsodium--1.0.20.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libsodium/1.0.20: 78 files, 883.4KB
# ==> Installing ffmpeg dependency: zeromq
# ==> Downloading https://ghcr.io/v2/homebrew/core/zeromq/manifests/4.3.5_1
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/27b053a576863f2b2aa214070e5737e3a0ce0a073760d26c39902468274880b1--zeromq-4.3.5_1.bottle_manifest.json
# ==> Pouring zeromq--4.3.5_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zeromq/4.3.5_1: 85 files, 6.2MB
# ==> Installing ffmpeg dependency: zimg
# ==> Downloading https://ghcr.io/v2/homebrew/core/zimg/manifests/3.0.5
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/f94d5d93fe440d14fe866ceb3ada13593ef4b17f58985ebb17ea4320168b65cd--zimg-3.0.5.bottle_manifest.json
# ==> Pouring zimg--3.0.5.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zimg/3.0.5: 28 files, 1.1MB
# ==> Installing ffmpeg
# ==> Pouring ffmpeg--7.1.1_1.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/ffmpeg/7.1.1_1: 287 files, 52.1MB
# ==> Running `brew cleanup ffmpeg`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading 3 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# git 2.46.1 -> 2.49.0, tcl-tk 8.6.15 -> 9.0.1, git-gui 2.46.1 -> 2.49.0
# ==> Downloading https://ghcr.io/v2/homebrew/core/git/manifests/2.49.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/manifests/9.0.1-1
# ######################################################################### 100.0%
# ==> Fetching dependencies for tcl-tk: libtommath
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtommath/manifests/1.3.0
# ######################################################################### 100.0%
# ==> Fetching libtommath
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtommath/blobs/sha256:180de0f
# ######################################################################### 100.0%
# ==> Fetching tcl-tk
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/blobs/sha256:27a8119fce7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/git-gui/manifests/2.49.0
# ######################################################################### 100.0%
# ==> Fetching dependencies for git-gui: tcl-tk@8
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/8/manifests/8.6.16
# ######################################################################### 100.0%
# ==> Fetching tcl-tk@8
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/8/blobs/sha256:f2bc0545e
# ######################################################################### 100.0%
# ==> Fetching git-gui
# ==> Downloading https://ghcr.io/v2/homebrew/core/git-gui/blobs/sha256:b23434b9e2
# ######################################################################### 100.0%
# ==> Upgrading tcl-tk
#   8.6.15 -> 9.0.1
# ==> Installing dependencies for tcl-tk: libtommath
# ==> Installing tcl-tk dependency: libtommath
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtommath/manifests/1.3.0
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/ef0348de57a0a05db93896c0262f3ca870cb09716b9ece7572affab5e7e52423--libtommath-1.3.0.bottle_manifest.json
# ==> Pouring libtommath--1.3.0.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtommath/1.3.0: 12 files, 530.6KB
# ==> Installing tcl-tk
# ==> Pouring tcl-tk--9.0.1.arm64_sequoia.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/tcl-tk/9.0.1: 3,150 files, 38MB
# ==> Running `brew cleanup tcl-tk`...
# Removing: /opt/homebrew/Cellar/tcl-tk/8.6.15... (3,070 files, 53.3MB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/tcl-tk_bottle_manifest--8.6.15... (11.7KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/tcl-tk--8.6.15... (8.5MB)
# ==> Upgrading git-gui
#   2.46.1 -> 2.49.0
# ==> Installing dependencies for git-gui: tcl-tk@8
# ==> Installing git-gui dependency: tcl-tk@8
# ==> Downloading https://ghcr.io/v2/homebrew/core/tcl-tk/8/manifests/8.6.16
# Already downloaded: /Users/samuelturner/Library/Caches/Homebrew/downloads/0f3c4492e61a4d8ba549c6ba073a8c5b781ae250211e9ed93f4be9faf88662a0--tcl-tk@8-8.6.16.bottle_manifest.json
# ==> Pouring tcl-tk@8--8.6.16.arm64_sequoia.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/tcl-tk@8/8.6.16: 3,070 files, 35.7MB
# ==> Installing git-gui
# ==> Pouring git-gui--2.49.0.all.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/git-gui/2.49.0: 80 files, 2.2MB
# ==> Running `brew cleanup git-gui`...
# Removing: /opt/homebrew/Cellar/git-gui/2.46.1... (80 files, 2.3MB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/git-gui_bottle_manifest--2.46.1... (2.4KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/git-gui--2.46.1... (480.6KB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> `brew cleanup` has not been run in the last 30 days, running now...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# Removing: /opt/homebrew/Cellar/ca-certificates/2024-07-02... (4 files, 231.4KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/ca-certificates_bottle_manifest--2024-07-02-1... (1.9KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/ca-certificates--2024-07-02... (129.1KB)
# Removing: /opt/homebrew/Cellar/gettext/0.22.5... (2,044 files, 24.4MB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/gettext_bottle_manifest--0.22.5... (11.5KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/gettext--0.22.5... (10.2MB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/git_bottle_manifest--2.46.1... (14.2KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/git--2.46.1... (19.3MB)
# Removing: /opt/homebrew/Cellar/openssl@3/3.3.2... (6,984 files, 32.5MB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/openssl@3_bottle_manifest--3.3.2... (13KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/openssl@3--3.3.2... (9.6MB)
# Removing: /opt/homebrew/Cellar/pcre2/10.44... (237 files, 6.3MB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/pcre2_bottle_manifest--10.44... (11.4KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/pcre2--10.44... (2MB)
# ==> Autoremoving 2 unneeded formulae:
# libtommath
# tcl-tk
# Uninstalling /opt/homebrew/Cellar/tcl-tk/9.0.1... (3,150 files, 38MB)
# Uninstalling /opt/homebrew/Cellar/libtommath/1.3.0... (12 files, 530.6KB)
# Removing: /Users/samuelturner/Library/Caches/Homebrew/portable-ruby-3.3.4_1.arm64_big_sur.bottle.tar.gz... (11.1MB)
# Removing: /Users/samuelturner/Library/Logs/Homebrew/openssl@3... (64B)
# Removing: /Users/samuelturner/Library/Logs/Homebrew/ca-certificates... (64B)
# Pruned 0 symbolic links and 2 directories from /opt/homebrew

# %%
import whisper

# %%
# Load a pre-trained model
model = whisper.load_model("base")  # Options: tiny, base, small, medium, large

# %%
filename = "audio/carlos-y-el-elefante.mp3"
result = model.transcribe(filename, language="es")
# Out:
# /Users/samuelturner/miniconda3/lib/python3.12/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
print(result)
# Out:
# {'text': " Hola, bienvenidos a la primera episodia de Simple Stories en Spanish. Today es una de mis favoritos. Yo he tenido esta historia de la primera vez en Spanish, que es la vez que me he hecho por cuatro años. Espero que te disfrutan. Carlos, el LLF. Hola, chico. El chico está en el parque. El nombre del chico es Carlos. Carlos está en el parque. Muchas personas están en el parque. Las personas corren en el parque. Carlos, no corre en el parque. Carlos se sienta en el parque. Carlos nira las personas que corren. Pero Carlos no corre. Carlos se sienta en el parque. En el parque, Carlos nira. Un LF. El LF. No se sienta. El LF. Corre. El LF. Corre en el parque. Carlos, se levanta. Y nira el LF. El LF. Corre. Y Carlos, corre tambien. Carlos, corre el LF. El LF. Corre y nira Carlos. El LF. Para. No corre más. El LF se sienta. Y nira Carlos. Carlos, corre. Carlos, corre al LF. El LF se levanta. Y Carlos para. El LF. Mira a Carlos. Carlos, miera el LF. Carlos. Toga el LF. El LF. Toga Carlos. El LF se sienta en el parque. Carlos, se sienta en el parque tambien. Piro Carlos, se sienta. Y nira el LF. En tonces, el LF. Célevanta. Célevanta, con Carlos. El LF. Corre. Corre, con Carlos. Aora. Carlos, se sienta en un LF. En el parque. Ay, ruchas personas en el parque. Carlos, no miera las personas. Carlos, miera. El LF. Las personas mieran el LF. Tambien. Miren El LFonde, con el Chico. Ok, Jorge. Al guy. planning of una historia pérdida por Kamila Bates. Ados miren las {\\an8m' de otra ф near】 jurídica,zt sino asociación media. Si terane ninguna répond materia, oré un video como un pedazo, killed remembering a mí, un blanco, transmis estar biencji stencil aJumel.com. No olvides de suscribirte que lesanga su premio de episodios de mudar de popo latino Нisbynich.", 'segments': [{'id': 0, 'seek': 0, 'start': 0.0, 'end': 5.6000000000000005, 'text': ' Hola, bienvenidos a la primera episodia de Simple Stories en Spanish.', 'tokens': [50364, 22637, 11, 3610, 40668, 257, 635, 17382, 39200, 654, 368, 21532, 31797, 465, 8058, 13, 50644], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compression_ratio': 1.5098039215686274, 'no_speech_prob': 0.20612803101539612}, {'id': 1, 'seek': 0, 'start': 5.6000000000000005, 'end': 8.82, 'text': ' Today es una de mis favoritos.', 'tokens': [50644, 314, 378, 320, 785, 2002, 368, 3346, 2294, 11343, 13, 50805], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compression_ratio': 1.5098039215686274, 'no_speech_prob': 0.20612803101539612}, {'id': 2, 'seek': 0, 'start': 8.82, 'end': 12.58, 'text': ' Yo he tenido esta historia de la primera vez en Spanish,', 'tokens': [50805, 7616, 415, 33104, 5283, 18385, 368, 635, 17382, 5715, 465, 8058, 11, 50993], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compression_ratio': 1.5098039215686274, 'no_speech_prob': 0.20612803101539612}, {'id': 3, 'seek': 0, 'start': 12.58, 'end': 16.02, 'text': ' que es la vez que me he hecho por cuatro años.', 'tokens': [50993, 631, 785, 635, 5715, 631, 385, 415, 13064, 1515, 28795, 11424, 13, 51165], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compression_ratio': 1.5098039215686274, 'no_speech_prob': 0.20612803101539612}, {'id': 4, 'seek': 0, 'start': 16.02, 'end': 17.740000000000002, 'text': ' Espero que te disfrutan.', 'tokens': [51165, 41831, 631, 535, 37114, 325, 282, 13, 51251], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compression_ratio': 1.5098039215686274, 'no_speech_prob': 0.20612803101539612}, {'id': 5, 'seek': 0, 'start': 17.740000000000002, 'end': 19.740000000000002, 'text': ' Carlos, el LLF.', 'tokens': [51251, 19646, 11, 806, 441, 43, 37, 13, 51351], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compression_ratio': 1.5098039215686274, 'no_speech_prob': 0.20612803101539612}, {'id': 6, 'seek': 0, 'start': 21.98, 'end': 23.48, 'text': ' Hola, chico.', 'tokens': [51463, 22637, 11, 417, 2789, 13, 51538], 'temperature': 0.0, 'avg_logprob': -0.9919013977050781, 'compr ...
